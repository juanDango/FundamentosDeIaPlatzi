# %%
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import seaborn as sns

# Cargar dataset
df_partidos = pd.read_csv('datos_cebollitas.csv')

df_partidos.head()
# Out:
#   fecha_partido     equipo_local equipo_visitante  goles_local  \
# 0    2023-01-01  Atlético Python    Cebollitas FC            2
# 1    2023-01-08       NumPy City  Atlético Python            1
# 2    2023-01-15    Cebollitas FC      Data United            1
# 3    2023-01-22  Atlético Python      Data United            2
# 4    2023-01-29      Data United    Cebollitas FC            5
#
#    goles_visitante  posesion_local (%)  posesion_visitante (%)  \
# 0                0                  54                      46
# 1                5                  60                      40
# 2                0                  55                      45
# 3                3                  57                      43
# 4                3                  52                      48
#
#    tiros_arco_local  tiros_arco_visitante       estadio
# 0                12                     6  Python Arena
# 1                12                     3    Estadio ML
# ...

# %%
scaler_norm = MinMaxScaler()

df_partidos['tiros_arco_local_norm'] = scaler_norm.fit_transform(df_partidos[['tiros_arco_local']])
df_partidos['tiros_arco_visitante_norm'] = scaler_norm.fit_transform(df_partidos[['tiros_arco_visitante']])

df_partidos[['tiros_arco_local', 'tiros_arco_local_norm', 'tiros_arco_visitante', 'tiros_arco_visitante_norm']].head()
# Out:
#    tiros_arco_local  tiros_arco_local_norm  tiros_arco_visitante  \
# 0                12               1.000000                     6
# 1                12               1.000000                     3
# 2                10               0.777778                     7
# 3                 3               0.000000                     3
# 4                 7               0.444444                    12
#
#    tiros_arco_visitante_norm
# 0                   0.333333
# 1                   0.000000
# 2                   0.444444
# 3                   0.000000
# 4                   1.000000

# %%
scaler_std = StandardScaler()

df_partidos['posesion_local_std'] = scaler_std.fit_transform(df_partidos[['posesion_local (%)']])
df_partidos['posesion_visitante_std'] = scaler_std.fit_transform(df_partidos[['posesion_visitante (%)']])

df_partidos[['posesion_local (%)', 'posesion_local_std', 'posesion_visitante (%)', 'posesion_visitante_std']].head()
# Out:
#    posesion_local (%)  posesion_local_std  posesion_visitante (%)  \
# 0                  54            0.624415                      46
# 1                  60            1.623479                      40
# 2                  55            0.790926                      45
# 3                  57            1.123947                      43
# 4                  52            0.291394                      48
#
#    posesion_visitante_std
# 0               -0.624415
# 1               -1.623479
# 2               -0.790926
# 3               -1.123947
# 4               -0.291394

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

sns.histplot(df_partidos['tiros_arco_local_norm'], bins=10, kde=True, ax=ax[0], color='blue')
ax[0].set_title('Distribución Tiros a Arco Local (Normalizado)')


sns.histplot(df_partidos['posesion_local_std'], bins=10, kde=True, ax=ax[1], color='green')
ax[1].set_title('Distribución Posesión Local (Estandarizado)')
plt.show()
